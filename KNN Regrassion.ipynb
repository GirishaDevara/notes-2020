# %% [markdown]
# [Equation](https://www.saedsayad.com/k_nearest_neighbors_reg.htm#:~:text=A%20simple%20implementation%20of%20KNN,distance%20functions%20as%20KNN%20classification.)

# %%
from pydataset import data
import pandas as pd
# Out:
# initiated datasets repo at: C:\Users\divya\.pydataset/

# %%
turnout_data = data('turnout')

# %%
turnout_data.sample(10)
# Out:
#        race  age  educate   income  vote
# 1428  white   57     10.0   6.3304     1
# 1713  white   58     12.0   6.3352     1
# 1465  white   67     12.0   2.1279     1
# 1269  white   78     17.0   4.3348     1
# 376   white   37     12.0   2.9170     1
# 1769  white   53     19.0  10.1506     1
# 1843  white   22     12.0   3.7042     0
# 1363  white   37     13.0   5.9469     1
# 734   white   28     11.0   0.7594     0
# 139   white   62     10.0   2.1885     0

# %%
turnout_data[turnout_data.vote == 0]
# Out:
#        race  age  educate  income  vote
# 2     white   51     10.0  1.8561     0
# 3     white   24     12.0  0.6304     0
# 7     white   40     12.0  4.2857     0
# 13    white   22     12.0  1.7443     0
# 14    white   60     12.0  0.2253     0
# ...     ...  ...      ...     ...   ...
# 1994  white   58     12.0  0.1936     0
# 1995  white   22      7.0  0.2364     0
# 1996  white   26     16.0  3.3834     0
# 1999  white   22     10.0  2.4811     0
# 2000  white   59     10.0  0.5523     0
#
# [508 rows x 5 columns]

# %%
turnout_data.describe()
# Out:
#                age      educate       income         vote
# count  2000.000000  2000.000000  2000.000000  2000.000000
# mean     45.296000    12.066750     3.886640     0.746000
# std      17.517415     3.369807     2.826851     0.435406
# min      17.000000     0.000000     0.000000     0.000000
# 25%      31.000000    10.000000     1.744300     0.000000
# 50%      42.000000    12.000000     3.350800     1.000000
# 75%      59.000000    14.000000     5.233100     1.000000
# max      95.000000    19.000000    14.924700     1.000000

# %%
data()
# Out:
#         dataset_id                                             title
# 0    AirPassengers       Monthly Airline Passenger Numbers 1949-1960
# 1          BJsales                 Sales Data with Leading Indicator
# 2              BOD                         Biochemical Oxygen Demand
# 3     Formaldehyde                     Determination of Formaldehyde
# 4     HairEyeColor         Hair and Eye Color of Statistics Students
# ..             ...                                               ...
# 752        VerbAgg                  Verbal Aggression item responses
# 753           cake                 Breakage Angle of Chocolate Cakes
# 754           cbpp                 Contagious bovine pleuropneumonia
# 755    grouseticks  Data on red grouse ticks from Elston et al. 2001
# 756     sleepstudy       Reaction times in a sleep deprivation study
#
# [757 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error

# %%
X=turnout_data[['educate','income','vote']]
y=turnout_data['age']
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.3,random_state=0)

# %% [markdown]
# **The mean squared error** tells you how close a regression line is to a set of points. It does this by taking the distances from the points to the regression line (these distances are the “errors”) and squaring them. The squaring is necessary to remove any negative signs. It also gives more weight to larger differences. It’s called the mean squared error as you’re finding the average of a set of errors.
#
# ![image.png](attachment:image.png)

# %%
from math import sqrt

# %%
clf=KNeighborsRegressor()
clf.fit(X_train,y_train)
y_pred=clf.predict(X_test)
print(sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# 16.815124144650255

# %%
clf.predict([[10.0,1.8561,0]])
# Out:
# array([51.6])
